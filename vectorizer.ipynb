# %%
from functions import vectorize_y_ser
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-27-4779d3c30abd> in <module>
# ----> 1 from functions import vectorize_y_ser
#
# ImportError: cannot import name 'vectorize_y_ser' from 'functions' (/Users/djbetts/Desktop/opinion_classifier/functions.py)

# %%
import datetime

# %%
import nltk
import string

# %%
import pandas as pd
import numpy as np

# %%
from collections import Counter

# %%
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
def vectorize_y_ser(ser):
    y = ser.copy()
    y.replace({'Op-Ed': 1,'News': 0}, inplace=True)
    return y

# %%
# %%time
#import csv

data = pd.read_csv('/Users/djbetts/Desktop/opinion_classifier/data/us_gov_pol.csv', index_col=0, low_memory=False)
# Out:
# CPU times: user 379 ms, sys: 75.5 ms, total: 455 ms
# Wall time: 458 ms

# %%
# %%time
df = data.copy()
# Out:
# CPU times: user 2 ms, sys: 336 µs, total: 2.34 ms
# Wall time: 2.27 ms

# %%
df.shape
# Out:
# (5816, 21)

# %%
#define X. X is currently pandas series of unsplit strings

X = df.text

# %%
#turn series into list...

corpus = list(X)

# %%
# define y as a series of op-ed or news

y = df.type_of_material

# %%
# %%time
# vectorize y in to (1, 0) (op-ed, news)

y = vectorize_y_ser(y)
# Out:
# CPU times: user 2.88 ms, sys: 763 µs, total: 3.64 ms
# Wall time: 3.07 ms

# %%
y.value_counts()
# Out:
# 0    4490
# 1    1326
# Name: type_of_material, dtype: int64

# %% [markdown]
# # remove punctuation

# %%
document = df.text.iloc[0]

# %%
#document

# %%
#function that removes string.punctuation w/out the '?'
def punc_strip(document):
    for char in document:
        if char in string.punctuation:
            document = document.replace(char, " ")
            
    return document

# %%
document = punc_strip(document)

# %%
'—' in string.punctuation
# Out:
# False

# %% [markdown]
# # stemming/lemmatization

# %%
snowball = SnowballStemmer('english')
wordnet = WordNetLemmatizer()

# %%
# %%time
def snowball_tokenize(doc):
    snowball = SnowballStemmer('english')
    return [snowball.stem(word) for word in word_tokenize(doc.lower())]
# Out:
# CPU times: user 5 µs, sys: 0 ns, total: 5 µs
# Wall time: 7.15 µs

# %%
# %%time
def wordnet_tokenize(doc):
    wordnet = WordNetLemmatizer()
    return  [wordnet.lemmatize(word) for word in word_tokenize(doc.lower())]
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.2 µs

# %%
document = snowball_tokenize(document)
document = punc_strip(document)
document
# Out:
# ['washington',
#  '—',
#  'feder',
#  'prosecutor',
#  'rebuf',
#  'a',
#  'judg',
#  '’',
#  's',
#  'order',
#  'to',
#  'releas',
#  'by',
#  'friday',
#  'high',
#  'classifi',
#  'transcript',
#  'of',
#  'discuss',
#  'that',
#  'michael',
#  't',
#  'flynn',
#  'the',
#  'presid',
#  '’',
#  's',
#  'former',
#  'nation',
#  'secur',
#  'advis',
#  'had',
#  'with',
#  'the',
#  'russian',
#  'ambassador',
#  'dure',
#  'the',
#  'presidenti',
#  'transit',
#  'the',
#  'transcript',
#  'between',
#  'mr',
#  'flynn',
#  'and',
#  'sergey',
#  'i',
#  'kislyak',
#  'former',
#  'russia',
#  '’',
#  's',
#  'top',
#  'diplomat',
#  'in',
#  'the',
#  'unit',
#  'state',
#  'were',
#  'expect',
#  'to',
#  'show',
#  'that',
#  'they',
#  'talk',
#  'in',
#  'decemb',
#  '2016',
#  'about',
#  'sanction',
#  'that',
#  'the',
#  'obama',
#  'administr',
#  'had',
#  'just',
#  'impos',
#  'on',
#  'russia',
#  'mr',
#  'flynn',
#  'initi',
#  'deni',
#  'those',
#  'exchang',
#  'about',
#  'sanction',
#  'both',
#  'to',
#  'trump',
#  'administr',
#  'offici',
#  'and',
#  'the',
#  'f',
#  'b',
#  'i',
#  'in',
#  'the',
#  'week',
#  'after',
#  'the',
#  'discuss',
#  'the',
#  'convers',
#  'prompt',
#  'concern',
#  'among',
#  'senior',
#  'obama',
#  'administr',
#  'offici',
#  'about',
#  'whether',
#  'the',
#  'trump',
#  'transit',
#  'team',
#  'was',
#  'flout',
#  'norm',
#  'about',
#  'hold',
#  'off',
#  'on',
#  'make',
#  'polici',
#  'until',
#  'after',
#  'take',
#  'offic',
#  'the',
#  'phone',
#  'call',
#  'were',
#  'also',
#  'at',
#  'the',
#  'center',
#  'of',
#  'the',
#  'scandal',
#  'that',
#  'eventu',
#  'prompt',
#  'mr',
#  'flynn',
#  '’',
#  's',
#  'ouster',
#  'just',
#  'week',
#  'into',
#  'presid',
#  'trump',
#  '’',
#  's',
#  'term',
#  'the',
#  'order',
#  'last',
#  'month',
#  'from',
#  'the',
#  'judg',
#  'emmet',
#  'g',
#  'sullivan',
#  'of',
#  'the',
#  'feder',
#  'district',
#  'court',
#  'in',
#  'the',
#  'district',
#  'of',
#  'columbia',
#  'was',
#  'unusu',
#  'the',
#  'transcript',
#  'came',
#  'from',
#  'a',
#  'secret',
#  'f',
#  'b',
#  'i',
#  'wiretap',
#  'of',
#  'mr',
#  'kislyak',
#  'and',
#  'their',
#  'releas',
#  'would',
#  'have',
#  'provid',
#  'an',
#  'extraordinarili',
#  'rare',
#  'look',
#  'at',
#  'the',
#  'fruit',
#  'of',
#  'the',
#  'govern',
#  '’',
#  's',
#  'eavesdrop',
#  'agent',
#  'routin',
#  'listen',
#  'to',
#  'wiretap',
#  'of',
#  'foreign',
#  'offici',
#  'but',
#  'they',
#  'remain',
#  'among',
#  'the',
#  'govern',
#  '’',
#  's',
#  'most',
#  'close',
#  'held',
#  'secret',
#  'the',
#  'call',
#  'between',
#  'mr',
#  'flynn',
#  'and',
#  'mr',
#  'kislyak',
#  'were',
#  'referenc',
#  'repeat',
#  'in',
#  'court',
#  'document',
#  'and',
#  'the',
#  'special',
#  'counsel',
#  '’',
#  's',
#  'report',
#  'on',
#  'russian',
#  'elect',
#  'interfer',
#  'but',
#  'never',
#  'releas',
#  'and',
#  'prosecutor',
#  'have',
#  'not',
#  'acknowledg',
#  'the',
#  'exist',
#  'of',
#  'the',
#  'wiretap',
#  'judg',
#  'sullivan',
#  'who',
#  'is',
#  'overse',
#  'mr',
#  'flynn',
#  '’',
#  's',
#  'case',
#  'order',
#  'that',
#  'audio',
#  'record',
#  'of',
#  'his',
#  'convers',
#  'with',
#  'mr',
#  'kislyak',
#  'be',
#  'made',
#  'public',
#  'along',
#  'with',
#  'a',
#  'voic',
#  'mail',
#  'messag',
#  'made',
#  'by',
#  'the',
#  'presid',
#  '’',
#  's',
#  'lawyer',
#  'the',
#  'justic',
#  'depart',
#  '’',
#  's',
#  'refus',
#  'to',
#  'compli',
#  'with',
#  'the',
#  'judg',
#  '’',
#  's',
#  'order',
#  'made',
#  'clear',
#  'that',
#  'prosecutor',
#  'had',
#  'no',
#  'interest',
#  'in',
#  'confirm',
#  'the',
#  'wiretap',
#  'which',
#  'was',
#  'approv',
#  'by',
#  'the',
#  'secret',
#  'foreign',
#  'intellig',
#  'surveil',
#  'court',
#  '“',
#  'this',
#  'would',
#  'be',
#  'a',
#  'rare',
#  'step',
#  'to',
#  'make',
#  'public',
#  '”',
#  'such',
#  'intellig',
#  'collect',
#  'said',
#  'joshua',
#  'geltzer',
#  'a',
#  'former',
#  'justic',
#  'depart',
#  'offici',
#  '“',
#  'what',
#  'you',
#  'see',
#  'in',
#  'today',
#  '’',
#  's',
#  'file',
#  'is',
#  'the',
#  'govern',
#  'tri',
#  'to',
#  'avoid',
#  'disclos',
#  'that',
#  'materi',
#  '”',
#  'instead',
#  'prosecutor',
#  'assert',
#  'that',
#  'they',
#  'did',
#  'not',
#  'need',
#  'to',
#  'provid',
#  'the',
#  'transcript',
#  'becaus',
#  'they',
#  'were',
#  'in',
#  'the',
#  'end',
#  'not',
#  'vital',
#  'to',
#  'the',
#  'prosecut',
#  'of',
#  'mr',
#  'flynn',
#  'he',
#  'plead',
#  'guilti',
#  'in',
#  'decemb',
#  '2017',
#  'to',
#  'lie',
#  'to',
#  'the',
#  'f',
#  'b',
#  'i',
#  'after',
#  'agent',
#  'interview',
#  'him',
#  'about',
#  'what',
#  'was',
#  'said',
#  'on',
#  'those',
#  'call',
#  '“',
#  'the',
#  'govern',
#  'further',
#  'repres',
#  'that',
#  'it',
#  'is',
#  'not',
#  'reli',
#  'on',
#  'ani',
#  'other',
#  'record',
#  'of',
#  'ani',
#  'person',
#  'for',
#  'purpos',
#  'of',
#  'establish',
#  'the',
#  'defend',
#  '’',
#  's',
#  'guilt',
#  'or',
#  'determin',
#  'his',
#  'sentenc',
#  'nor',
#  'are',
#  'there',
#  'ani',
#  'other',
#  'record',
#  'that',
#  'are',
#  'part',
#  'of',
#  'the',
#  'sentenc',
#  'record',
#  '”',
#  'prosecutor',
#  'wrote',
#  'in',
#  'a',
#  'court',
#  'file',
#  'respond',
#  'to',
#  'judg',
#  'sullivan',
#  '’',
#  's',
#  'order',
#  'in',
#  'anoth',
#  'file',
#  'on',
#  'friday',
#  'prosecutor',
#  'did',
#  'compli',
#  'with',
#  'judg',
#  'sullivan',
#  '’',
#  's',
#  'order',
#  'to',
#  'make',
#  'public',
#  'the',
#  'messag',
#  'that',
#  'mr',
#  'trump',
#  '’',
#  's',
#  'former',
#  'person',
#  'lawyer',
#  'john',
#  'dowd',
#  'left',
#  'for',
#  'mr',
#  'flynn',
#  '’',
#  's',
#  'lawyer',
#  'robert',
#  'k',
#  'kelner',
#  'mr',
#  'dowd',
#  'left',
#  'the',
#  'messag',
#  'after',
#  'learn',
#  'on',
#  'nov',
#  '22',
#  '2017',
#  'that',
#  'mr',
#  'flynn',
#  'had',
#  'withdrawn',
#  'from',
#  'a',
#  'joint',
#  'defens',
#  'agreement',
#  'with',
#  'the',
#  'presid',
#  'the',
#  'content',
#  'of',
#  'that',
#  'voic',
#  'mail',
#  'were',
#  'first',
#  'disclos',
#  'in',
#  'april',
#  'in',
#  'mr',
#  'mueller',
#  '’',
#  's',
#  'report',
#  'in',
#  'a',
#  'statement',
#  'mr',
#  'dowd',
#  'call',
#  'the',
#  'special',
#  'counsel',
#  '’',
#  's',
#  'report',
#  '“',
#  'a',
#  'baseless',
#  'polit',
#  'document',
#  'design',
#  'to',
#  'smear',
#  'and',
#  'damag',
#  'the',
#  'reput',
#  'of',
#  'counsel',
#  'and',
#  'innoc',
#  'peopl',
#  '”',
#  'he',
#  'also',
#  'said',
#  'that',
#  'mr',
#  'mueller',
#  'never',
#  'ask',
#  'him',
#  'about',
#  'the',
#  'voic',
#  'mail',
#  '“',
#  'despit',
#  'numer',
#  'opportun',
#  'to',
#  'do',
#  'so',
#  '”',
#  'mr',
#  'flynn',
#  '’',
#  's',
#  'call',
#  'with',
#  'mr',
#  'kislyak',
#  'took',
#  'place',
#  'after',
#  'the',
#  'obama',
#  'administr',
#  'had',
#  'impos',
#  'sanction',
#  'on',
#  'moscow',
#  'for',
#  'interf',
#  'in',
#  'the',
#  '2016',
#  'presidenti',
#  'elect',
#  'the',
#  'sanction',
#  'alarm',
#  'trump',
#  'transit',
#  'offici',
#  'who',
#  'were',
#  'hope',
#  'to',
#  'improv',
#  'relat',
#  'with',
#  'the',
#  'russian',
#  'govern',
#  'mr',
#  'flynn',
#  'had',
#  'ask',
#  'mr',
#  'kislyak',
#  'that',
#  'russia',
#  'refrain',
#  'from',
#  'escal',
#  'tension',
#  'in',
#  'respons',
#  'to',
#  'the',
#  'obama',
#  'administr',
#  '’',
#  's',
#  'sanction',
#  'on',
#  'moscow',
#  'for',
#  'interf',
#  'in',
#  'the',
#  '2016',
#  'elect',
#  'when',
#  'question',
#  'by',
#  'the',
#  'f',
#  'b',
#  'i',
#  'on',
#  'jan',
#  '24',
#  '2017',
#  'mr',
#  'flynn',
#  'told',
#  'agent',
#  'that',
#  'he',
#  'had',
#  'not',
#  'made',
#  'that',
#  'request',
#  'he',
#  'also',
#  'lie',
#  'about',
#  'discuss',
#  'russia',
#  '’',
#  's',
#  'vote',
#  'on',
#  'an',
#  'impend',
#  'unit',
#  'nation',
#  'resolut',
#  'to',
#  'condemn',
#  'isra',
#  'settlement',
#  'in',
#  'the',
#  'west',
#  'bank',
#  'he',
#  'has',
#  'sinc',
#  'admit',
#  'that',
#  'he',
#  'ask',
#  'that',
#  'russia',
#  'either',
#  'delay',
#  'or',
#  'oppos',
#  'the',
#  'resolut',
#  '“',
#  'f',
#  'b',
#  'i',
#  'agent',
#  'gave',
#  'the',
#  'defend',
#  'multipl',
#  'opportun',
#  'to',
#  'correct',
#  'his',
#  'fals',
#  'statement',
#  'by',
#  'revisit',
#  'key',
#  'question',
#  '”',
#  'prosecutor',
#  'wrote',
#  'in',
#  'a',
#  'sentenc',
#  'memo',
#  'in',
#  'decemb',
#  '“',
#  'when',
#  'the',
#  'defend',
#  'said',
#  'he',
#  'did',
#  'not',
#  'rememb',
#  'someth',
#  'they',
#  'knew',
#  'he',
#  'said',
#  'they',
#  'use',
#  'the',
#  'exact',
#  'word',
#  'the',
#  'defend',
#  'had',
#  'use',
#  'in',
#  'order',
#  'to',
#  'prompt',
#  'a',
#  'truth',
#  'respons',
#  '”',
#  'in',
#  'earli',
#  'februari',
#  '2017',
#  'white',
#  'hous',
#  'offici',
#  'review',
#  'for',
#  'about',
#  'an',
#  'hour',
#  'the',
#  'transcript',
#  'of',
#  'call',
#  'between',
#  'mr',
#  'flynn',
#  'and',
#  'mr',
#  'kislyak',
#  'accord',
#  'to',
#  'a',
#  'confidenti',
#  'memo',
#  'by',
#  'white',
#  'hous',
#  'lawyer',
#  'that',
#  'detail',
#  'how',
#  'some',
#  'of',
#  'mr',
#  'trump',
#  '’',
#  's',
#  'advis',
#  'confront',
#  'the',
#  'situat',
#  'surround',
#  'mr',
#  'flynn',
#  'vice',
#  'presid',
#  'mike',
#  'penc',
#  'review',
#  'at',
#  'least',
#  'some',
#  'portion',
#  'of',
#  'the',
#  'transcript',
#  'accord',
#  'to',
#  'the',
#  'memo',
#  'mr',
#  'trump',
#  'fire',
#  'mr',
#  'flynn',
#  'that',
#  'month',
#  'after',
#  'administr',
#  'offici',
#  'conclud',
#  'base',
#  'on',
#  'their',
#  'review',
#  'of',
#  'the',
#  'transcript',
#  'that',
#  'he',
#  'had',
#  'been',
#  'untruth',
#  'to',
#  'mr',
#  'penc',
#  'and',
#  'other',
#  'offici',
#  'about',
#  'the',
#  'substanc',
#  'of',
#  'his',
#  'talk',
#  'with',
#  'mr',
#  'kislyak',
#  'mr',
#  'flynn',
#  '’',
#  's',
#  'support',
#  'and',
#  'the',
#  'white',
#  'hous',
#  'have',
#  'tri',
#  'to',
#  'play',
#  'down',
#  'his',
#  'action',
#  'suggest',
#  'that',
#  'investig',
#  'entrap',
#  'him',
#  'or',
#  'that',
#  'his',
#  'bodi',
#  'languag',
#  'dure',
#  'the',
#  'interview',
#  'with',
#  'agent',
#  'show',
#  'he',
#  'was',
#  'not',
#  'lie',
#  'judg',
#  'sullivan',
#  'rebuk',
#  'mr',
#  'flynn',
#  'for',
#  'his',
#  'conduct',
#  'and',
#  'rais',
#  'concern',
#  'that',
#  'mr',
#  'flynn',
#  '’',
#  's',
#  'lawyer',
#  'were',
#  'suggest',
#  'in',
#  'presentenc',
#  'memo',
#  'that',
#  'the',
#  'f',
#  'b',
#  'i',
#  'agent',
#  'who',
#  'question',
#  'him',
#  'may',
#  'have',
#  'trick',
#  'him',
#  'by',
#  'fail',
#  'to',
#  'warn',
#  'that',
#  'lie',
#  'to',
#  'investig',
#  'was',
#  'a',
#  'crime',
#  '“',
#  'this',
#  'sound',
#  'like',
#  'a',
#  'backped',
#  ...]
